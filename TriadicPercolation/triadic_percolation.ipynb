# %%
from func import *

N = 1000
c = 30
cp = 10
cn = 2.5
Tmax = 200
num = 50

# %%
p_list, R_list = triadic_percolation_simulation_poisson(
    N, c, cp, cn, Tmax, num)
plt.scatter(p_list, R_list)
plt.show()
# Out:
# 0.0
# 0.02
# 0.04
# 0.06
# 0.08
# 0.1
# 0.12
# 0.14
# 0.16
# 0.18
# 0.2
# 0.22
# 0.24
# 0.26
# 0.28
# 0.3
# 0.32
# 0.34
# 0.36
# 0.38
# 0.4
# 0.42
# 0.44
# 0.46
# 0.48
# 0.5
# 0.52
# 0.54
# 0.56
# 0.58
# 0.6
# 0.62
# 0.64
# 0.66
# 0.68
# 0.7000000000000001
# 0.72
# 0.74
# 0.76
# 0.78
# 0.8
# 0.8200000000000001
# 0.84
# 0.86
# 0.88
# 0.9
# 0.92
# 0.9400000000000001
# 0.96
# 0.98

# %%
p_list, R_list = triadic_percolation_theory_poisson(c, cp, cn, Tmax, num)
plt.scatter(p_list, R_list)
plt.show()
