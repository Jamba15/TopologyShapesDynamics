# %% [markdown]
# #  Triadic Percolation

# %% [markdown]
# This notebook shows simulation and theoretical results on examples of Triadic Percolation on networks with triadic interactions.

# %%
# Install celluloid for producing the movies shown in the paper
# !pip install celluloid
from functions_triadic import *
# Out:
# Requirement already satisfied: celluloid in /Users/hanlin/anaconda3/envs/TopologyShapesDynamics/lib/python3.10/site-packages (0.2.0)
# Requirement already satisfied: matplotlib in /Users/hanlin/anaconda3/envs/TopologyShapesDynamics/lib/python3.10/site-packages (from celluloid) (3.6.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/hanlin/anaconda3/envs/TopologyShapesDynamics/lib/python3.10/site-packages (from matplotlib->celluloid) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/hanlin/anaconda3/envs/TopologyShapesDynamics/lib/python3.10/site-packages (from matplotlib->celluloid) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/hanlin/anaconda3/envs/TopologyShapesDynamics/lib/python3.10/site-packages (from matplotlib->celluloid) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/hanlin/anaconda3/envs/TopologyShapesDynamics/lib/python3.10/site-packages (from matplotlib->celluloid) (1.4.5)
# Requirement already satisfied: numpy>=1.19 in /Users/hanlin/anaconda3/envs/TopologyShapesDynamics/lib/python3.10/site-packages (from matplotlib->celluloid) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /Users/hanlin/anaconda3/envs/TopologyShapesDynamics/lib/python3.10/site-packages (from matplotlib->celluloid) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/hanlin/anaconda3/envs/TopologyShapesDynamics/lib/python3.10/site-packages (from matplotlib->celluloid) (10.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/hanlin/anaconda3/envs/TopologyShapesDynamics/lib/python3.10/site-packages (from matplotlib->celluloid) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/hanlin/anaconda3/envs/TopologyShapesDynamics/lib/python3.10/site-packages (from matplotlib->celluloid) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/hanlin/anaconda3/envs/TopologyShapesDynamics/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->celluloid) (1.16.0)

# %% [markdown]
# # Triadic percolation on Poisson higher-order networks with triadic interactions.

# %% [markdown]
# We consider Poisson higher-order networks with triadic interactions. Having a Poisson structural network with average degree `c`. The number of positive and negative regulator nodes displays a Poisson distribution with average degree `cp` and `cn` respectively. We first show the ordinary percolation on a Poisson network where triadic interactions are not present. The percolation displays a continuous second order phase transition. The dynamics is iterated until `t=Tmax` and the final `num` of points are collected to produce the figure.
# The phase transition in absence of triadic interactions is shown in the following figure. The order parameter (the fraction of nodes in the giant component denoted as $R$) displays a continuous second order phase transition.

# %%
config = config_parser('ordinary_percolation.yml')
p_list, R_list = triadic_percolation_theory_poisson(config, "none")
plot_orbit_diagram(p_list, R_list)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 113.61it/s]

# %% [markdown]
# When triadic interactions are present, the phase diagram becomes a orbit diagram and the order parameter (the fraction of nodes in the giant component denoted as $R$) displays period doubling and a route to chaos.

# %%
config = config_parser('triadic_percolation.yml')
p_list, R_list = triadic_percolation_theory_poisson(config)
plot_orbit_diagram(p_list, R_list)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 111.04it/s]

# %% [markdown]
# The time series of the dynamic is shown at a given $p$. The following figure shows a chaotic time series of the order parameter (the fraction of nodes in the giant component denoted as $R$) at $p=0.3$ (this can be changed in the configuration file named `chaotic_timeseries.yml`).

# %%
config = config_parser('chaotic_timeseries.yml')
T_list, R_list = triadic_percolation_theory_poisson_time_series(config)
plot_time_series(T_list, R_list)

# %% [markdown]
# # Movies of periodic and chaotic oscillation of network activity
#
# Here we show an example that the regulation is formed exclusively by negative regulations (positive regulation is not required to activate a link). A period-2 oscillation (blinking) is observed.
# A GIF movie named `blinking.gif` is generated.

# %%
config = config_parser('blinking_movie.yml')
regulation = "exclu_neg"    # Regulatory interactions are formed exclusively by negative regulations
movie_name = "blinking"
triadic_percolation_simulation_poisson_movie(config, movie_name, regulation)
# Out:
# 0

# %% [markdown]
# This is an general example that both positive and negative regulations are present. A chaotic oscillation is observed. Due to the chaotic nature and stochasticity, every realization will not be the same.
# A GIF movie named `chaos.gif` is generated and saved in the current working directory.

# %%
config = config_parser('chaos_movie.yml')
movie_name = "chaos"
triadic_percolation_simulation_poisson_movie(config, movie_name)
# Out:
# 0
